# %% [markdown]
# # About
# This document is used to create URLs for views into the [Ecosystem Dashboard](https://github.com/ipfs-shipyard/ecosystem-dashboard) that help with weekly maintenance triage.
#
# This is part of the [202103 Proposal for PL Public GitHub Repository Maintenance](https://www.notion.so/protocollabs/202103-Proposal-for-PL-Public-GitHub-Repository-Maintenance-fed8bb8bf73b418d9ebe9dd30c854d74).
#
# The links generated by this notebook are usually copy/pasted into:
# * [InterPlanetary JS Issue Triage Notes](https://docs.google.com/document/d/1EKg3i6zBPjcfQfFClRr9H0EsbPz3mlmV0mIcpdrDZI0/edit)
# * [InterPlanetary Go Issue Triage Notes](https://docs.google.com/document/d/1Vs-htsHJ9yaLGxP6oVxoyf50N0DmlhaqKRpayrOujzU/edit#heading=h.ccvl36wlizuw)
# * [Filecoin Issue Triage Notes](https://docs.google.com/document/d/1wbNWXYrO-nlavoeLI6ua3DP2BYTKSI9_1pBbcOd2bXs/edit)

# %% [markdown]
# # Helper Functions
# These are helper functions for creating the triage hyperlinks.

# %%
from urllib.parse import urlparse, parse_qs, urlunparse, urlencode
from IPython.display import HTML

# Wrapper around create_triage_hyperlink that outputs HTML hyperlink in the cell output.
def display_triage_hyperlink(query_string_descriptions_to_parts_dict, domain="ecosystem-research.herokuapp.com"):
    display(HTML(create_triage_hyperlink(query_string_descriptions_to_parts_dict, domain)))

# Create HTML anchor tag with a friendly description based on the provided map.
# See below for usage examples.
def create_triage_hyperlink(query_string_descriptions_to_parts_dict, domain="ecosystem-research.herokuapp.com"):
    # Merge in all the maps that are provided in query_string_descriptions_to_parts_dict
    # https://stackoverflow.com/a/37358304/16318
    query_string_parts = {key:val for d in query_string_descriptions_to_parts_dict.values() for key,val in d.items()}
    triage_url = create_triage_url(query_string_parts, domain)
    description = " ".join(query_string_descriptions_to_parts_dict.keys())
    return f'<a href="{triage_url}">{description}</a>'

# Create a URL to the ecosystem dashboard.
# Domain is overrideable since Filecoin dashboard has different domain.
def create_triage_url(query_string_parts, domain="ecosystem-research.herokuapp.com", path="/all"):
    url_parts = {
        "scheme" : 'https', 
        "netloc" : domain, 
        "path" : path, 
        "params" : '', 
        "query" : urlencode(query_string_parts, doseq=True), 
        "fragment" : ''
    }
    return urlunparse(url_parts.values())

# Gets a map of the query string parts from a URL. 
# Useful for going from an ecosystem dashboard URL to code.
def get_query_string_parts(url):
    return parse_qs(urlparse(url).query)

# %% [markdown]
# # Ecosystem Dashboard Query Parameters
# Below are various maps of Ecosystem Dashboard query parameters that can beused to create different URLs.

# %%
# TODO: give a better names to this.
# These are the parameters that are useful for all URLs so far.
base_base_qs_parts = {
    'state': 'open',
    "per_page" : 100,
    'sort': 'updated_at',
    'order': 'asc',
    "exclude_org[]" : ["ipfs-shipyard", "ProtoSchool", "ChainSafe", "NodeFactoryIo",],
    "exclude_repo_full_name[]" : ["libp2p/go-smart-record"],
}
base_qs_parts = base_base_qs_parts | {
    'range': '90',
    "no_boards" : "true",
}
most_recent = {
    'sort': 'updated_at',
    'order': 'desc',
}
js = {
    "language" : "JS",
    'range': '180',
}
go = {"language" : "Go"}
collabs = {
    'only_collabs': 'true',
    "exclude_core" : "true",
    'range': '365',
}
community = {
    'community': 'true',
    "exclude_core" : "true",
}
core = { # PL employees
    "only_core" : "true",
}
no_reponse = {'no_response': 'true'}
pull_requests = {'type': 'pull_requests'}
issues = {'type': 'issues'}
exclude_labels_where_already_triaged_list = ["status/ready", "ready", "status/in-progress", "status/blocked", "need/analysis", 'kind/question', "question", "exploration", "kind/discussion", "need/author-input"]
exclude_labels_where_already_triaged = {
    'exclude_label[]': exclude_labels_where_already_triaged_list,
}
need_author_input = base_base_qs_parts | {
    'label[]': ["need/author-input"],
    'range': '365', # specify a range so that a default value isn't used
}
need_triage_label = {'label[]': ["need/triage"],}
blocked_label = {'label[]': ["status/blocked"],}
in_progress_label = {'label[]': ["status/in-progress"],}
ready_label = {'label[]': ["status/ready"],}
exclude_labels_where_already_triaged_and_need_triage = {
    'exclude_label[]': exclude_labels_where_already_triaged_list + ["need/triage"]
}

# %% [markdown]
# # IP JS

# %%
# One-off: need author input
display_triage_hyperlink({
    "js" : js,
    "need/author-input" : need_author_input,
})
# Out:
# <a href="https://ecosystem-research.herokuapp.com/all?language=JS&range=365&state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&label%5B%5D=need%2Fauthor-input">js need/author-input</a>

# %%
# Collabs
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "collabs" : collabs,
    "PRs" : pull_requests
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "collabs" : collabs,
    "issues" : issues,
    "non-triaged" : exclude_labels_where_already_triaged,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "collabs" : collabs,
    "issues" : issues,
    "status/blocked" : blocked_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "collabs" : collabs,
    "issues" : issues,
    "status/in-progress" : in_progress_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "collabs" : collabs,
    "issues" : issues,
    "status/ready" : ready_label,
    " " : most_recent,
})
# Out:
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=JS&only_collabs=true&exclude_core=true&type=pull_requests"> js collabs PRs</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=JS&only_collabs=true&exclude_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input"> js collabs issues non-triaged</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=JS&only_collabs=true&exclude_core=true&type=issues&label%5B%5D=status%2Fblocked"> js collabs issues status/blocked</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=JS&only_collabs=true&exclude_core=true&type=issues&label%5B%5D=status%2Fin-progress"> js collabs issues status/in-progress</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=desc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=JS&only_collabs=true&exclude_core=true&type=issues&label%5B%5D=status%2Fready"> js collabs issues status/ready  </a>

# %%
# Community
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "community" : community,
    "PRs" : pull_requests
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "community" : community,
    "issues" : issues,
    "need/triage" : need_triage_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "community" : community,
    "issues" : issues,
    "non-triaged (excludes need/triage)" : exclude_labels_where_already_triaged_and_need_triage,
    "no-response" : no_reponse,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "community" : community,
    "issues" : issues,
    "non-triaged (excludes need/triage)" : exclude_labels_where_already_triaged_and_need_triage,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "community" : community,
    "issues" : issues,
    "status/blocked" : blocked_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "community" : community,
    "issues" : issues,
    "status/in-progress" : in_progress_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "community" : community,
    "issues" : issues,
    "status/ready" : ready_label,
    " " : most_recent,
})
# Out:
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&community=true&exclude_core=true&type=pull_requests"> js community PRs</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&community=true&exclude_core=true&type=issues&label%5B%5D=need%2Ftriage"> js community issues need/triage</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&community=true&exclude_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input&exclude_label%5B%5D=need%2Ftriage&no_response=true"> js community issues non-triaged (excludes need/triage) no-response</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&community=true&exclude_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input&exclude_label%5B%5D=need%2Ftriage"> js community issues non-triaged (excludes need/triage)</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&community=true&exclude_core=true&type=issues&label%5B%5D=status%2Fblocked"> js community issues status/blocked</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&community=true&exclude_core=true&type=issues&label%5B%5D=status%2Fin-progress"> js community issues status/in-progress</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=desc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&community=true&exclude_core=true&type=issues&label%5B%5D=status%2Fready"> js community issues status/ready  </a>

# %%
# Core
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "core" : core,
    "PRs" : pull_requests
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "core" : core,
    "issues" : issues,
    "need/triage" : need_triage_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "core" : core,
    "issues" : issues,
    "non-triaged (excludes need/triage)" : exclude_labels_where_already_triaged_and_need_triage,
    "no-response" : no_reponse,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "core" : core,
    "issues" : issues,
    "non-triaged (excludes need/triage)" : exclude_labels_where_already_triaged_and_need_triage,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "core" : core,
    "issues" : issues,
    "status/blocked" : blocked_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "core" : core,
    "issues" : issues,
    "status/in-progress" : in_progress_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "js" : js,
    "core" : core,
    "issues" : issues,
    "status/ready" : ready_label,
    " " : most_recent,
})
# Out:
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&only_core=true&type=pull_requests"> js core PRs</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&only_core=true&type=issues&label%5B%5D=need%2Ftriage"> js core issues need/triage</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&only_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input&exclude_label%5B%5D=need%2Ftriage&no_response=true"> js core issues non-triaged (excludes need/triage) no-response</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&only_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input&exclude_label%5B%5D=need%2Ftriage"> js core issues non-triaged (excludes need/triage)</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&only_core=true&type=issues&label%5B%5D=status%2Fblocked"> js core issues status/blocked</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&only_core=true&type=issues&label%5B%5D=status%2Fin-progress"> js core issues status/in-progress</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=desc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=180&no_boards=true&language=JS&only_core=true&type=issues&label%5B%5D=status%2Fready"> js core issues status/ready  </a>

# %% [markdown]
# # IP Go

# %%
# One-off: need author input
display_triage_hyperlink({
    "go" : go,
    "need/author-input" : need_author_input,
})
# Out:
# <a href="https://ecosystem-research.herokuapp.com/all?language=Go&state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&label%5B%5D=need%2Fauthor-input&range=365">go need/author-input</a>

# %%
# Collabs
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "collabs" : collabs,
    "PRs" : pull_requests
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "collabs" : collabs,
    "issues" : issues,
    "non-triaged" : exclude_labels_where_already_triaged,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "collabs" : collabs,
    "issues" : issues,
    "status/blocked" : blocked_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "collabs" : collabs,
    "issues" : issues,
    "status/in-progress" : in_progress_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "collabs" : collabs,
    "issues" : issues,
    "status/ready" : ready_label,
    " " : most_recent,
})
# Out:
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=Go&only_collabs=true&exclude_core=true&type=pull_requests"> go collabs PRs</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=Go&only_collabs=true&exclude_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input"> go collabs issues non-triaged</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=Go&only_collabs=true&exclude_core=true&type=issues&label%5B%5D=status%2Fblocked"> go collabs issues status/blocked</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=Go&only_collabs=true&exclude_core=true&type=issues&label%5B%5D=status%2Fin-progress"> go collabs issues status/in-progress</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=desc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=365&no_boards=true&language=Go&only_collabs=true&exclude_core=true&type=issues&label%5B%5D=status%2Fready"> go collabs issues status/ready  </a>

# %%
# Community
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "community" : community,
    "PRs" : pull_requests
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "community" : community,
    "issues" : issues,
    "need/triage" : need_triage_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "community" : community,
    "issues" : issues,
    "non-triaged (excludes need/triage)" : exclude_labels_where_already_triaged_and_need_triage,
    "no-response" : no_reponse,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "community" : community,
    "issues" : issues,
    "non-triaged (excludes need/triage)" : exclude_labels_where_already_triaged_and_need_triage,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "community" : community,
    "issues" : issues,
    "status/blocked" : blocked_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "community" : community,
    "issues" : issues,
    "status/in-progress" : in_progress_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "community" : community,
    "issues" : issues,
    "status/ready" : ready_label,
    " " : most_recent,
})
# Out:
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&community=true&exclude_core=true&type=pull_requests"> go community PRs</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&community=true&exclude_core=true&type=issues&label%5B%5D=need%2Ftriage"> go community issues need/triage</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&community=true&exclude_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input&exclude_label%5B%5D=need%2Ftriage&no_response=true"> go community issues non-triaged (excludes need/triage) no-response</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&community=true&exclude_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input&exclude_label%5B%5D=need%2Ftriage"> go community issues non-triaged (excludes need/triage)</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&community=true&exclude_core=true&type=issues&label%5B%5D=status%2Fblocked"> go community issues status/blocked</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&community=true&exclude_core=true&type=issues&label%5B%5D=status%2Fin-progress"> go community issues status/in-progress</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=desc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&community=true&exclude_core=true&type=issues&label%5B%5D=status%2Fready"> go community issues status/ready  </a>

# %%
# Core
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "core" : core,
    "PRs" : pull_requests
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "core" : core,
    "issues" : issues,
    "need/triage" : need_triage_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "core" : core,
    "issues" : issues,
    "non-triaged (excludes need/triage)" : exclude_labels_where_already_triaged_and_need_triage,
    "no-response" : no_reponse,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "core" : core,
    "issues" : issues,
    "non-triaged (excludes need/triage)" : exclude_labels_where_already_triaged_and_need_triage,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "core" : core,
    "issues" : issues,
    "status/blocked" : blocked_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "core" : core,
    "issues" : issues,
    "status/in-progress" : in_progress_label,
})
display_triage_hyperlink({
    "" : base_qs_parts,
    "go" : go,
    "core" : core,
    "issues" : issues,
    "status/ready" : ready_label,
    " " : most_recent,
})
# Out:
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&only_core=true&type=pull_requests"> go core PRs</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&only_core=true&type=issues&label%5B%5D=need%2Ftriage"> go core issues need/triage</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&only_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input&exclude_label%5B%5D=need%2Ftriage&no_response=true"> go core issues non-triaged (excludes need/triage) no-response</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&only_core=true&type=issues&exclude_label%5B%5D=status%2Fready&exclude_label%5B%5D=ready&exclude_label%5B%5D=status%2Fin-progress&exclude_label%5B%5D=status%2Fblocked&exclude_label%5B%5D=need%2Fanalysis&exclude_label%5B%5D=kind%2Fquestion&exclude_label%5B%5D=question&exclude_label%5B%5D=exploration&exclude_label%5B%5D=kind%2Fdiscussion&exclude_label%5B%5D=need%2Fauthor-input&exclude_label%5B%5D=need%2Ftriage"> go core issues non-triaged (excludes need/triage)</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&only_core=true&type=issues&label%5B%5D=status%2Fblocked"> go core issues status/blocked</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=asc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&only_core=true&type=issues&label%5B%5D=status%2Fin-progress"> go core issues status/in-progress</a>
# <a href="https://ecosystem-research.herokuapp.com/all?state=open&per_page=100&sort=updated_at&order=desc&exclude_org%5B%5D=ipfs-shipyard&exclude_org%5B%5D=ProtoSchool&exclude_org%5B%5D=ChainSafe&exclude_org%5B%5D=NodeFactoryIo&exclude_repo_full_name%5B%5D=libp2p%2Fgo-smart-record&range=90&no_boards=true&language=Go&only_core=true&type=issues&label%5B%5D=status%2Fready"> go core issues status/ready  </a>

# %% [markdown]
# # Filecoin

# %%
filecoin_base_qs_parts = {
    'sort': 'updated_at',
    'order': 'asc',
    'range': '90',
    'state': 'open',
    "per_page" : 100,
    "exclude_org[]" : [
        "filecoin-shipyard",
        "nftstorage",
        "web3-storage",
    ],
    'exclude_repo_full_name[]': [
        'filecoin-project/community',
        'filecoin-project/cpp-filecoin',
        'filecoin-project/devgrants',
        'filecoin-project/filecoin-docs',
        'filecoin-project/go-fil-commp-hashhash',
        'filecoin-project/helm-charts',
        'filecoin-project/neptune',
        'filecoin-project/notary-governance',
        'filecoin-shipyard/powergate-pinning-service',
        'filecoin-project/rust-fil-proofs',
        'filecoin-project/rust-filecoin-proofs-api',
        'filecoin-project/sentinel-visor',
        'filecoin-project/slate',
        'filecoin-project/slingshot',
        'filecoin-project/venus',
        'filecoin-project/venus-auth',
        'filecoin-project/venus-docs',
        'filecoin-project/venus-messager',
        'filecoin-project/venus-miner',
        'filecoin-project/venus-sealer',
        'filecoin-project/venus-wallet',
    ],
    "no_boards" : "true",
}
display_triage_hyperlink({
    "filecoin" : filecoin_base_qs_parts,
    "collabs" : collabs,
    "PRs" : pull_requests
}, "filecoin.ecosystem-dashboard.com")
display_triage_hyperlink({
    "filecoin" : filecoin_base_qs_parts,
    "community" : community,
    "PRs" : pull_requests
}, "filecoin.ecosystem-dashboard.com")
display_triage_hyperlink({
    "filecoin" : filecoin_base_qs_parts,
    "core" : core,
    "PRs" : pull_requests
}, "filecoin.ecosystem-dashboard.com")
# Out:
# <a href="https://filecoin.ecosystem-dashboard.com/all?sort=updated_at&order=asc&range=365&state=open&per_page=100&exclude_org%5B%5D=filecoin-shipyard&exclude_org%5B%5D=nftstorage&exclude_org%5B%5D=web3-storage&exclude_repo_full_name%5B%5D=filecoin-project%2Fcommunity&exclude_repo_full_name%5B%5D=filecoin-project%2Fcpp-filecoin&exclude_repo_full_name%5B%5D=filecoin-project%2Fdevgrants&exclude_repo_full_name%5B%5D=filecoin-project%2Ffilecoin-docs&exclude_repo_full_name%5B%5D=filecoin-project%2Fgo-fil-commp-hashhash&exclude_repo_full_name%5B%5D=filecoin-project%2Fhelm-charts&exclude_repo_full_name%5B%5D=filecoin-project%2Fneptune&exclude_repo_full_name%5B%5D=filecoin-project%2Fnotary-governance&exclude_repo_full_name%5B%5D=filecoin-shipyard%2Fpowergate-pinning-service&exclude_repo_full_name%5B%5D=filecoin-project%2Frust-fil-proofs&exclude_repo_full_name%5B%5D=filecoin-project%2Frust-filecoin-proofs-api&exclude_repo_full_name%5B%5D=filecoin-project%2Fsentinel-visor&exclude_repo_full_name%5B%5D=filecoin-project%2Fslate&exclude_repo_full_name%5B%5D=filecoin-project%2Fslingshot&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-auth&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-docs&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-messager&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-miner&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-sealer&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-wallet&no_boards=true&only_collabs=true&exclude_core=true&type=pull_requests">filecoin collabs PRs</a>
# <a href="https://filecoin.ecosystem-dashboard.com/all?sort=updated_at&order=asc&range=90&state=open&per_page=100&exclude_org%5B%5D=filecoin-shipyard&exclude_org%5B%5D=nftstorage&exclude_org%5B%5D=web3-storage&exclude_repo_full_name%5B%5D=filecoin-project%2Fcommunity&exclude_repo_full_name%5B%5D=filecoin-project%2Fcpp-filecoin&exclude_repo_full_name%5B%5D=filecoin-project%2Fdevgrants&exclude_repo_full_name%5B%5D=filecoin-project%2Ffilecoin-docs&exclude_repo_full_name%5B%5D=filecoin-project%2Fgo-fil-commp-hashhash&exclude_repo_full_name%5B%5D=filecoin-project%2Fhelm-charts&exclude_repo_full_name%5B%5D=filecoin-project%2Fneptune&exclude_repo_full_name%5B%5D=filecoin-project%2Fnotary-governance&exclude_repo_full_name%5B%5D=filecoin-shipyard%2Fpowergate-pinning-service&exclude_repo_full_name%5B%5D=filecoin-project%2Frust-fil-proofs&exclude_repo_full_name%5B%5D=filecoin-project%2Frust-filecoin-proofs-api&exclude_repo_full_name%5B%5D=filecoin-project%2Fsentinel-visor&exclude_repo_full_name%5B%5D=filecoin-project%2Fslate&exclude_repo_full_name%5B%5D=filecoin-project%2Fslingshot&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-auth&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-docs&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-messager&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-miner&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-sealer&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-wallet&no_boards=true&community=true&exclude_core=true&type=pull_requests">filecoin community PRs</a>
# <a href="https://filecoin.ecosystem-dashboard.com/all?sort=updated_at&order=asc&range=90&state=open&per_page=100&exclude_org%5B%5D=filecoin-shipyard&exclude_org%5B%5D=nftstorage&exclude_org%5B%5D=web3-storage&exclude_repo_full_name%5B%5D=filecoin-project%2Fcommunity&exclude_repo_full_name%5B%5D=filecoin-project%2Fcpp-filecoin&exclude_repo_full_name%5B%5D=filecoin-project%2Fdevgrants&exclude_repo_full_name%5B%5D=filecoin-project%2Ffilecoin-docs&exclude_repo_full_name%5B%5D=filecoin-project%2Fgo-fil-commp-hashhash&exclude_repo_full_name%5B%5D=filecoin-project%2Fhelm-charts&exclude_repo_full_name%5B%5D=filecoin-project%2Fneptune&exclude_repo_full_name%5B%5D=filecoin-project%2Fnotary-governance&exclude_repo_full_name%5B%5D=filecoin-shipyard%2Fpowergate-pinning-service&exclude_repo_full_name%5B%5D=filecoin-project%2Frust-fil-proofs&exclude_repo_full_name%5B%5D=filecoin-project%2Frust-filecoin-proofs-api&exclude_repo_full_name%5B%5D=filecoin-project%2Fsentinel-visor&exclude_repo_full_name%5B%5D=filecoin-project%2Fslate&exclude_repo_full_name%5B%5D=filecoin-project%2Fslingshot&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-auth&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-docs&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-messager&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-miner&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-sealer&exclude_repo_full_name%5B%5D=filecoin-project%2Fvenus-wallet&no_boards=true&only_core=true&type=pull_requests">filecoin core PRs</a>
